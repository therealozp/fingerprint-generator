# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import torchvision.transforms.functional as TF
import torchvision.transforms as transforms
import cv2

import math

import os

# %%
def box_sum_same(x: torch.Tensor, w: int, pad_mode: str = "replicate"):
    """
    x: (N,1,H,W)
    returns: (N,1,H,W) where each pixel is sum over a w×w window
    """
    assert w % 2 == 1, "Window size must be odd"
    pad_size = w // 2
    y = F.avg_pool2d(x, kernel_size=w, stride=1, padding=pad_size) * (w * w)
    return y

# %%
def get_blockwise_orientation(
    source_image: torch.Tensor,
    block_size: int = 8,
):
    dev = source_image.device
    dtype = source_image.dtype

    sobel_x = torch.tensor(
        [[-1, 0, 1], [-2, 0, 2], [-1, 0, 1]], dtype=dtype, device=dev
    ).view(1, 1, 3, 3)
    sobel_y = torch.tensor(
        [[-1, -2, -1], [0, 0, 0], [1, 2, 1]], dtype=dtype, device=dev
    ).view(1, 1, 3, 3)
    blur = transforms.GaussianBlur(kernel_size=5)

    img = source_image.clone()
    img = blur(img.unsqueeze(0).unsqueeze(0)).squeeze(0).squeeze(0)

    Gx = F.conv2d(img.unsqueeze(0).unsqueeze(0), sobel_x, padding=1)
    Gy = F.conv2d(img.unsqueeze(0).unsqueeze(0), sobel_y, padding=1)

    Gx2 = Gx * Gx
    Gy2 = Gy * Gy
    Gxy = Gx * Gy

    kernel = torch.ones(
        (1, 1, block_size, block_size), dtype=Gx2.dtype, device=Gx2.device
    )

    sum_Gx2 = F.avg_pool2d(Gx2, kernel_size=block_size, stride=block_size) * (
        block_size * block_size
    )
    sum_Gy2 = F.avg_pool2d(Gy2, kernel_size=block_size, stride=block_size) * (
        block_size * block_size
    )
    sum_Gxy = F.avg_pool2d(Gxy, kernel_size=block_size, stride=block_size) * (
        block_size * block_size
    )

    Vx = 2.0 * sum_Gxy.squeeze(0).squeeze(0)
    Vy = sum_Gx2.squeeze(0).squeeze(0) - sum_Gy2.squeeze(0).squeeze(0)

    theta = 0.5 * torch.atan2(Vx, Vy + 1e-8)

    Tx = torch.cos(2.0 * theta)
    Ty = torch.sin(2.0 * theta)

    Tprime_x = blur(Tx.unsqueeze(0).unsqueeze(0)).squeeze(0).squeeze(0)
    Tprime_y = blur(Ty.unsqueeze(0).unsqueeze(0)).squeeze(0).squeeze(0)

    theta = 0.5 * torch.atan2(Tprime_y, Tprime_x)
    orientation_map = torch.remainder(theta, torch.pi)

    return orientation_map

def get_freq_map(
    img: torch.Tensor
):
    # dummy values for now
    return torch.full_like(img, 0.35)


def compute_spatial_gradient(tensor_map):
    kernel_x = (
        torch.tensor([[-1.0, 0.0, 1.0]], device=tensor_map.device).view(1, 1, 1, 3) / 2.0
    )
    kernel_y = (
        torch.tensor([[-1.0], [0.0], [1.0]], device=tensor_map.device).view(1, 1, 3, 1)
        / 2.0
    )

    dx = F.conv2d(tensor_map.unsqueeze(0).unsqueeze(0), kernel_x, padding=(0, 1)).squeeze(0).squeeze(0)
    dy = F.conv2d(tensor_map.unsqueeze(0).unsqueeze(0), kernel_y, padding=(1, 0)).squeeze(0).squeeze(0)

    return dx, dy


def compute_phasor_gradient(phase_map):
    # Convert to complex phasor: e^(i * phi)
    phasor = torch.exp(1j * phase_map)

    # Gradient in X
    # Conj(x) * x_next is equivalent to e^(-i*phi) * e^(i*phi_next) = e^(i * d_phi)
    # The angle of this result gives the wrapped difference in range [-pi, pi]
    diff_x = phasor[..., :, 1:] * torch.conj(phasor[..., :, :-1])
    dx = torch.angle(diff_x)
    dx = F.pad(dx, (0, 1, 0, 0))  # Pad to match size

    # Gradient in Y
    diff_y = phasor[..., 1:, :] * torch.conj(phasor[..., :-1, :])
    dy = torch.angle(diff_y)
    dy = F.pad(dy, (0, 0, 0, 1))

    return dx, dy


def structure_loss(phase_c_params, spiral_phase, target_vector_field):
    # dx_c, dy_c = compute_spatial_gradient(phase_c_params)
    # dx_s, dy_s = compute_spatial_gradient(spiral_phase)

    dx_c, dy_c = compute_phasor_gradient(phase_c_params)
    dx_s, dy_s = compute_phasor_gradient(spiral_phase)

    grad_total_x = dx_c + dx_s
    grad_total_y = dy_c + dy_s

    loss_flow = F.mse_loss(grad_total_x, target_vector_field[:, 0]) + F.mse_loss(
        grad_total_y, target_vector_field[:, 1]
    )

    return loss_flow


def ssim_loss(generated, target, window_size=11):
    """
    Basic implementation of SSIM as a loss (1 - SSIM).
    assumes images are shape [Batch, 1, H, W]
    """
    # Create a simple gaussian window
    sigma = 1.5
    gauss = torch.arange(window_size, dtype=torch.float32) - window_size // 2
    gauss = torch.exp(-(gauss**2) / (2 * sigma**2))
    gauss = gauss / gauss.sum()
    window = gauss[:, None] @ gauss[None, :]
    window = window.to(generated.device).view(1, 1, window_size, window_size)

    # Helper to filter
    def filter2d(img):
        return F.conv2d(img, window, padding=window_size // 2, groups=1)

    mu1 = filter2d(generated)
    mu2 = filter2d(target)

    mu1_sq = mu1**2
    mu2_sq = mu2**2
    mu1_mu2 = mu1 * mu2

    sigma1_sq = filter2d(generated**2) - mu1_sq
    sigma2_sq = filter2d(target**2) - mu2_sq
    sigma12 = filter2d(generated * target) - mu1_mu2

    C1 = 0.01**2
    C2 = 0.03**2

    ssim_map = ((2 * mu1_mu2 + C1) * (2 * sigma12 + C2)) / (
        (mu1_sq + mu2_sq + C1) * (sigma1_sq + sigma2_sq + C2)
    )

    return 1 - ssim_map.mean()


def spectral_loss(pred, target):
    eps = 1e-8
    fft_pred = torch.fft.rfft2(pred, norm="ortho")
    fft_target = torch.fft.rfft2(target, norm="ortho")

    mag_pred = torch.abs(fft_pred)
    mag_target = torch.abs(fft_target)

    log_mag_pred = torch.log(mag_pred + eps)
    log_mag_target = torch.log(mag_target + eps)

    return F.l1_loss(log_mag_pred, log_mag_target)

# from https://openaccess.thecvf.com/content/ICCV2021/papers/Jiang_Focal_Frequency_Loss_for_Image_Reconstruction_and_Synthesis_ICCV_2021_paper.pdf
def focal_loss(pred, target, alpha=1.0):
    eps = 1e-8
    fft_pred = torch.fft.rfft2(pred, norm="ortho")
    fft_target = torch.fft.rfft2(target, norm="ortho")

    diff_fft_val = fft_target - fft_pred
    diff_fft_mag = torch.abs(diff_fft_val)

    distance = torch.square(diff_fft_mag)
    weight = torch.pow(diff_fft_mag, alpha)

    return torch.mean(weight * distance)

def fft_loss(pred, target):
    eps = 1e-8
    fft_pred = torch.fft.rfft2(pred, norm="ortho")
    fft_target = torch.fft.rfft2(target, norm="ortho")

    real_pred = torch.real(fft_pred)
    imag_pred = torch.imag(fft_pred)

    real_target = torch.real(fft_target)
    imag_target = torch.imag(fft_target)

    return F.mse_loss(real_pred, real_target) + F.mse_loss(imag_pred, imag_target)


def multiscale_mse_loss(pred, target, scales=[1, 2, 4, 8, 16]):
    loss = 0
    for scale in scales:
        if scale == 1:
            loss += F.mse_loss(pred, target)
        else:
            p_down = F.avg_pool2d(pred.unsqueeze(0).unsqueeze(0), kernel_size=scale, stride=scale)
            t_down = F.avg_pool2d(target.unsqueeze(0).unsqueeze(0), kernel_size=scale, stride=scale)
            loss += F.mse_loss(p_down, t_down)
    return loss

# %%
def train_structure_loss(
    target_image, n_epochs, target_vector_field, spiral_phase_map=None, lr=5e-1
):
    h, w = target_image.shape
    # phase_map = torch.zeros_like(target_image, requires_grad=True)
    x_coords = torch.linspace(torch.pi, 2 * torch.pi, w)
    y_coords = torch.linspace(torch.pi, 2 * torch.pi, h)
    yy, xx = torch.meshgrid(y_coords, x_coords, indexing="ij")
    phase_init = xx
    phase_map = nn.Parameter(phase_init.clone())

    if spiral_phase_map is None:
        spiral_phase_map = torch.zeros_like(target_image, requires_grad=False)

    # training settings
    optimizer = torch.optim.Adam([phase_map], lr=lr)

    for epoch in range(n_epochs):
        optimizer.zero_grad()
        generated_fingerprint = 0.5 * ( 
            1.0 + torch.cos(phase_map + spiral_phase_map)
        )

        recon_loss = multiscale_mse_loss(
            generated_fingerprint, target_image
        )

        structure_simil_loss = ssim_loss(
            generated_fingerprint.unsqueeze(0).unsqueeze(0),
            target_image.unsqueeze(0).unsqueeze(0),
        )
        structure_l = structure_loss(
            phase_map, spiral_phase_map, target_vector_field=target_vector_field
        )
        spectral_l = focal_loss(generated_fingerprint, target_image)

        alpha = epoch / n_epochs / 50.0  # Ramp up from 0 to 1 over 500 epochs
        recon_loss_weight = 5.0 
        ssim_loss_weight = 5.0 
        total_loss = 0.0 * structure_l + recon_loss_weight * recon_loss + ssim_loss_weight * structure_simil_loss + alpha * spectral_l

        # Backpropagate and update parameters
        total_loss.backward()
        optimizer.step()

        # Print loss values
        if epoch % 100 == 0 or epoch == 1 or epoch == n_epochs - 1:
            print(f"Structure Loss: {structure_l:.6f} | Recon Loss: {recon_loss:.6f} | Structure Simil Loss: {structure_simil_loss:.6f} | Spectral loss: {spectral_l:.6f} | Total Loss: {total_loss:.6f}")

    return phase_map

# %%
def train_spiral_no_spiral(
    target_image_with_spiral, target_image_without_spiral, n_epochs, spiral_phase_map=None, lr=5e-1
):
    assert target_image_with_spiral.shape == target_image_without_spiral.shape, "Input images must have the same shape"
    h, w = target_image_with_spiral.shape
    # phase_map = torch.zeros_like(target_image, requires_grad=True)
    x_coords = torch.linspace(torch.pi, 2 * torch.pi, w)
    y_coords = torch.linspace(torch.pi, 2 * torch.pi, h)
    yy, xx = torch.meshgrid(y_coords, x_coords, indexing="ij")
    phase_init = xx
    phase_map = nn.Parameter(phase_init.clone())

    if spiral_phase_map is None:
        spiral_phase_map = torch.zeros_like(target_image_with_spiral, requires_grad=False)

    # training settings
    optimizer = torch.optim.Adam([phase_map], lr=lr)

    for epoch in range(n_epochs):
        optimizer.zero_grad()
        generated_fingerprint_with_spiral = 0.5 * (1.0 + torch.cos(phase_map + spiral_phase_map))

        recon_loss = multiscale_mse_loss(generated_fingerprint_with_spiral, target_image_with_spiral)
        structure_simil_loss = ssim_loss(
            generated_fingerprint_with_spiral
            .unsqueeze(0).unsqueeze(0),
            target_image_with_spiral.unsqueeze(0).unsqueeze(0),
        )

        generated_fingerprint_no_spiral = 0.5 * (1.0 + torch.cos(phase_map))
        phaseless_recon_loss = multiscale_mse_loss(generated_fingerprint_no_spiral, target_image_without_spiral)
        ssim_no_spiral_loss = ssim_loss(
            generated_fingerprint_no_spiral.unsqueeze(0).unsqueeze(0),
            target_image_without_spiral.unsqueeze(0).unsqueeze(0),
        )


        recon_loss_weight = 5.0
        ssim_loss_weight = 5.0
        total_loss = (
            + recon_loss_weight * recon_loss
            + ssim_loss_weight * structure_simil_loss
            + recon_loss_weight * phaseless_recon_loss
            + ssim_loss_weight * ssim_no_spiral_loss
        )

        # Backpropagate and update parameters
        total_loss.backward()
        optimizer.step()

        # Print loss values
        if epoch % 100 == 0 or epoch == 1 or epoch == n_epochs - 1:
            print(
                f"Recon Loss: {recon_loss:.6f} | SSIM Loss: {structure_simil_loss:.6f} | Phaseless Recon Loss: {phaseless_recon_loss:.6f} | SSIM No Spiral Loss: {ssim_no_spiral_loss:.6f} | Total Loss: {total_loss:.6f}"
            )

    return phase_map

# %%
def wrap_to_pi(x):
    """Wraps phase to (-pi, pi]"""
    return (x + np.pi / 2.0) % (np.pi) - np.pi /2.0


def itoh_2d_unwrap(wrapped_phase):
    rows, cols = wrapped_phase.shape
    unwrapped_phase = np.zeros_like(wrapped_phase)

    # 1. Initialize starting point
    unwrapped_phase[0, 0] = wrapped_phase[0, 0]

    # 2. Unwrap the first row (Reference)
    for j in range(1, cols):
        diff = wrapped_phase[0, j] - wrapped_phase[0, j - 1]
        unwrapped_phase[0, j] = unwrapped_phase[0, j - 1] + wrap_to_pi(diff)

    # 3. Unwrap all columns using the first row as the seed
    for j in range(cols):
        for i in range(1, rows):
            diff = wrapped_phase[i, j] - wrapped_phase[i - 1, j]
            unwrapped_phase[i, j] = unwrapped_phase[i - 1, j] + wrap_to_pi(diff)

    return unwrapped_phase


def unwrap(orientation_map):
    """
    Implements the greedy unwrapping strategy from Feng & Jain Eq. 12.
    Expects orientation_map in radians, wrapped in [0, pi] or [-pi/2, pi/2].
    """
    if torch.is_tensor(orientation_map):
        ori = orientation_map.detach().cpu().numpy()
    else:
        ori = orientation_map.copy()
    
    unwrapped = itoh_2d_unwrap(ori)
    print("Unwrapped orientation map min/max:", unwrapped.min(), unwrapped.max())
    return torch.from_numpy(unwrapped)

def fix_edges(mp):
    mask = torch.ones_like(mp)
    mask[..., 0, :] = 0  # Top
    mask[..., -1, :] = 0  # Bottom
    mask[..., :, 0] = 0  # Left
    mask[..., :, -1] = 0  # Right

    # 2. Convolution logic to average valid neighbors
    kernel = torch.ones(1, 1, 3, 3, device=mp.device)
    to_conv = mp * mask
    print("2conv shape", to_conv.shape)

    neighbor_sum = (
        F.conv2d(to_conv.unsqueeze(0).unsqueeze(0), kernel, padding=1).squeeze(0).squeeze(0)
    )
    neighbor_count = (
        F.conv2d(mask.unsqueeze(0).unsqueeze(0), kernel, padding=1).squeeze(0).squeeze(0)
    )

    neighbor_count[neighbor_count == 0] = 1
    interpolated = neighbor_sum / neighbor_count

    # 4. Replace ONLY the border pixels
    return torch.where(mask.bool(), mp, interpolated)

# %%
from torchvision import transforms

spiral_image = cv2.imread("images/spiral_phase.jpg", cv2.IMREAD_GRAYSCALE)
spiral_image = spiral_image / 255.0
h, w = spiral_image.shape

# normalize
target_spiral_image = torch.from_numpy(spiral_image).float()
target_spiral_image = target_spiral_image / target_spiral_image.max()

non_spiral_image = cv2.imread("images/cont_phase.jpg", cv2.IMREAD_GRAYSCALE)
non_spiral_image = non_spiral_image / 255.0

target_non_spiral_image = torch.from_numpy(non_spiral_image).float()
target_non_spiral_image = target_non_spiral_image / target_non_spiral_image.max()

# plt.imshow(target_spiral_image.numpy(), cmap="gray")
# plt.axis("off")
# plt.colorbar()
# plt.show()
# spiral phase initialization
spiral_phase_coords = [(95, 128), (40, 55), (128, 200)]
spiral_phase_polarities = [+1, -1, -1]

spiral_phase = torch.zeros(h, w)
y_range = torch.arange(h)
x_range = torch.arange(w)

Y, X = torch.meshgrid(y_range, x_range, indexing="ij")
for (yy, xx), polarity in zip(spiral_phase_coords, spiral_phase_polarities):
    spiral_phase += polarity * torch.arctan2(Y - yy, X - xx)

spiral_phase_map = torch.tensor(spiral_phase, requires_grad=False)
# Out:
# C:\Users\leanh\AppData\Local\Temp\ipykernel_21500\2068163624.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   spiral_phase_map = torch.tensor(spiral_phase, requires_grad=False)

# %%
# phase_map = torch.acos(target_image) - spiral_phase_map
phase_map = train_spiral_no_spiral(
    target_image_with_spiral=target_spiral_image,
    target_image_without_spiral=target_non_spiral_image,
    n_epochs=10000,
    spiral_phase_map=spiral_phase_map,
    lr=1e-3
)

plt.imshow(phase_map.detach().cpu().numpy(), cmap="gray")
final_trained_fingerprint = 0.5 * (1.0 + torch.cos(phase_map + spiral_phase_map))
# Out:
# Recon Loss: 1.064909 | SSIM Loss: 0.947302 | Phaseless Recon Loss: 1.066201 | SSIM No Spiral Loss: 0.953782 | Total Loss: 20.160969
# Recon Loss: 1.064263 | SSIM Loss: 0.946386 | Phaseless Recon Loss: 1.065485 | SSIM No Spiral Loss: 0.952805 | Total Loss: 20.144699
# Recon Loss: 0.997398 | SSIM Loss: 0.858757 | Phaseless Recon Loss: 0.992317 | SSIM No Spiral Loss: 0.859789 | Total Loss: 18.541309
# Recon Loss: 0.925169 | SSIM Loss: 0.781982 | Phaseless Recon Loss: 0.915235 | SSIM No Spiral Loss: 0.778762 | Total Loss: 17.005741
# Recon Loss: 0.850116 | SSIM Loss: 0.714806 | Phaseless Recon Loss: 0.836657 | SSIM No Spiral Loss: 0.708091 | Total Loss: 15.548344
# Recon Loss: 0.773909 | SSIM Loss: 0.654864 | Phaseless Recon Loss: 0.758023 | SSIM No Spiral Loss: 0.645317 | Total Loss: 14.160564
# Recon Loss: 0.698532 | SSIM Loss: 0.601110 | Phaseless Recon Loss: 0.681039 | SSIM No Spiral Loss: 0.589540 | Total Loss: 12.851110
# Recon Loss: 0.625900 | SSIM Loss: 0.552907 | Phaseless Recon Loss: 0.607421 | SSIM No Spiral Loss: 0.540121 | Total Loss: 11.631746
# Recon Loss: 0.557510 | SSIM Loss: 0.509828 | Phaseless Recon Loss: 0.538605 | SSIM No Spiral Loss: 0.496360 | Total Loss: 10.511518
# Recon Loss: 0.494281 | SSIM Loss: 0.471616 | Phaseless Recon Loss: 0.475552 | SSIM No Spiral Loss: 0.457565 | Total Loss: 9.495068
# Recon Loss: 0.436588 | SSIM Loss: 0.438025 | Phaseless Recon Loss: 0.418680 | SSIM No Spiral Loss: 0.423105 | Total Loss: 8.581996
# Recon Loss: 0.384363 | SSIM Loss: 0.408671 | Phaseless Recon Loss: 0.367936 | SSIM No Spiral Loss: 0.392459 | Total Loss: 7.767147
# Recon Loss: 0.337268 | SSIM Loss: 0.383130 | Phaseless Recon Loss: 0.322724 | SSIM No Spiral Loss: 0.365100 | Total Loss: 7.041111
# Recon Loss: 0.294839 | SSIM Loss: 0.360634 | Phaseless Recon Loss: 0.282205 | SSIM No Spiral Loss: 0.340436 | Total Loss: 6.390568
# Recon Loss: 0.256759 | SSIM Loss: 0.340371 | Phaseless Recon Loss: 0.245606 | SSIM No Spiral Loss: 0.317658 | Total Loss: 5.801968
# Recon Loss: 0.223095 | SSIM Loss: 0.321642 | Phaseless Recon Loss: 0.212284 | SSIM No Spiral Loss: 0.295643 | Total Loss: 5.263320
# Recon Loss: 0.194206 | SSIM Loss: 0.303817 | Phaseless Recon Loss: 0.181987 | SSIM No Spiral Loss: 0.273496 | Total Loss: 4.767534
# Recon Loss: 0.170061 | SSIM Loss: 0.286493 | Phaseless Recon Loss: 0.155200 | SSIM No Spiral Loss: 0.251327 | Total Loss: 4.315408
# Recon Loss: 0.150174 | SSIM Loss: 0.269724 | Phaseless Recon Loss: 0.132431 | SSIM No Spiral Loss: 0.229961 | Total Loss: 3.911448
# Recon Loss: 0.133813 | SSIM Loss: 0.253623 | Phaseless Recon Loss: 0.113627 | SSIM No Spiral Loss: 0.210267 | Total Loss: 3.556648
# Recon Loss: 0.120295 | SSIM Loss: 0.238307 | Phaseless Recon Loss: 0.098278 | SSIM No Spiral Loss: 0.192602 | Total Loss: 3.247412
# Recon Loss: 0.109013 | SSIM Loss: 0.223846 | Phaseless Recon Loss: 0.085797 | SSIM No Spiral Loss: 0.176926 | Total Loss: 2.977912
# Recon Loss: 0.099564 | SSIM Loss: 0.210454 | Phaseless Recon Loss: 0.075642 | SSIM No Spiral Loss: 0.162950 | Total Loss: 2.743050
# Recon Loss: 0.091672 | SSIM Loss: 0.198319 | Phaseless Recon Loss: 0.067318 | SSIM No Spiral Loss: 0.150391 | Total Loss: 2.538498
# Recon Loss: 0.084956 | SSIM Loss: 0.187379 | Phaseless Recon Loss: 0.060500 | SSIM No Spiral Loss: 0.139234 | Total Loss: 2.360344
# Recon Loss: 0.079056 | SSIM Loss: 0.177507 | Phaseless Recon Loss: 0.054921 | SSIM No Spiral Loss: 0.129488 | Total Loss: 2.204859
# Recon Loss: 0.073685 | SSIM Loss: 0.168493 | Phaseless Recon Loss: 0.050348 | SSIM No Spiral Loss: 0.121051 | Total Loss: 2.067886
# Recon Loss: 0.068699 | SSIM Loss: 0.160167 | Phaseless Recon Loss: 0.046579 | SSIM No Spiral Loss: 0.113772 | Total Loss: 1.946087
# Recon Loss: 0.064025 | SSIM Loss: 0.152382 | Phaseless Recon Loss: 0.043441 | SSIM No Spiral Loss: 0.107593 | Total Loss: 1.837206
# Recon Loss: 0.059569 | SSIM Loss: 0.144861 | Phaseless Recon Loss: 0.040863 | SSIM No Spiral Loss: 0.102517 | Total Loss: 1.739052
# Recon Loss: 0.055293 | SSIM Loss: 0.137492 | Phaseless Recon Loss: 0.038796 | SSIM No Spiral Loss: 0.098419 | Total Loss: 1.650004
# Recon Loss: 0.051204 | SSIM Loss: 0.130293 | Phaseless Recon Loss: 0.037131 | SSIM No Spiral Loss: 0.095062 | Total Loss: 1.568455
# Recon Loss: 0.047316 | SSIM Loss: 0.123220 | Phaseless Recon Loss: 0.035763 | SSIM No Spiral Loss: 0.092218 | Total Loss: 1.492586
# Recon Loss: 0.043628 | SSIM Loss: 0.116189 | Phaseless Recon Loss: 0.034637 | SSIM No Spiral Loss: 0.089715 | Total Loss: 1.420846
# Recon Loss: 0.040227 | SSIM Loss: 0.109344 | Phaseless Recon Loss: 0.033629 | SSIM No Spiral Loss: 0.087231 | Total Loss: 1.352153
# Recon Loss: 0.037254 | SSIM Loss: 0.103045 | Phaseless Recon Loss: 0.032561 | SSIM No Spiral Loss: 0.084552 | Total Loss: 1.287063
# Recon Loss: 0.034723 | SSIM Loss: 0.097468 | Phaseless Recon Loss: 0.031354 | SSIM No Spiral Loss: 0.081679 | Total Loss: 1.226123
# Recon Loss: 0.032585 | SSIM Loss: 0.092583 | Phaseless Recon Loss: 0.030037 | SSIM No Spiral Loss: 0.078630 | Total Loss: 1.169174
# Recon Loss: 0.030808 | SSIM Loss: 0.088383 | Phaseless Recon Loss: 0.028647 | SSIM No Spiral Loss: 0.075499 | Total Loss: 1.116680
# Recon Loss: 0.029309 | SSIM Loss: 0.084941 | Phaseless Recon Loss: 0.027253 | SSIM No Spiral Loss: 0.072543 | Total Loss: 1.070229
# Recon Loss: 0.027963 | SSIM Loss: 0.082120 | Phaseless Recon Loss: 0.025962 | SSIM No Spiral Loss: 0.070019 | Total Loss: 1.030322
# Recon Loss: 0.026739 | SSIM Loss: 0.079754 | Phaseless Recon Loss: 0.024833 | SSIM No Spiral Loss: 0.067889 | Total Loss: 0.996077
# Recon Loss: 0.025645 | SSIM Loss: 0.077705 | Phaseless Recon Loss: 0.023864 | SSIM No Spiral Loss: 0.066117 | Total Loss: 0.966656
# Recon Loss: 0.024620 | SSIM Loss: 0.075675 | Phaseless Recon Loss: 0.023084 | SSIM No Spiral Loss: 0.064774 | Total Loss: 0.940767
# Recon Loss: 0.023675 | SSIM Loss: 0.073620 | Phaseless Recon Loss: 0.022491 | SSIM No Spiral Loss: 0.063765 | Total Loss: 0.917761
# Recon Loss: 0.022862 | SSIM Loss: 0.071754 | Phaseless Recon Loss: 0.022036 | SSIM No Spiral Loss: 0.062973 | Total Loss: 0.898126
# Recon Loss: 0.022196 | SSIM Loss: 0.070221 | Phaseless Recon Loss: 0.021673 | SSIM No Spiral Loss: 0.062315 | Total Loss: 0.882027
# Recon Loss: 0.021644 | SSIM Loss: 0.068985 | Phaseless Recon Loss: 0.021368 | SSIM No Spiral Loss: 0.061754 | Total Loss: 0.868753
# Recon Loss: 0.021167 | SSIM Loss: 0.067892 | Phaseless Recon Loss: 0.021099 | SSIM No Spiral Loss: 0.061247 | Total Loss: 0.857026
# Recon Loss: 0.020750 | SSIM Loss: 0.066868 | Phaseless Recon Loss: 0.020869 | SSIM No Spiral Loss: 0.060769 | Total Loss: 0.846285
# Recon Loss: 0.020389 | SSIM Loss: 0.065917 | Phaseless Recon Loss: 0.020685 | SSIM No Spiral Loss: 0.060353 | Total Loss: 0.836717
# Recon Loss: 0.020096 | SSIM Loss: 0.065114 | Phaseless Recon Loss: 0.020535 | SSIM No Spiral Loss: 0.059990 | Total Loss: 0.828673
# Recon Loss: 0.019844 | SSIM Loss: 0.064421 | Phaseless Recon Loss: 0.020423 | SSIM No Spiral Loss: 0.059732 | Total Loss: 0.822105
# Recon Loss: 0.019626 | SSIM Loss: 0.063830 | Phaseless Recon Loss: 0.020336 | SSIM No Spiral Loss: 0.059551 | Total Loss: 0.816709
# Recon Loss: 0.019447 | SSIM Loss: 0.063370 | Phaseless Recon Loss: 0.020254 | SSIM No Spiral Loss: 0.059359 | Total Loss: 0.812153
# Recon Loss: 0.019301 | SSIM Loss: 0.063005 | Phaseless Recon Loss: 0.020175 | SSIM No Spiral Loss: 0.059161 | Total Loss: 0.808211
# Recon Loss: 0.019172 | SSIM Loss: 0.062683 | Phaseless Recon Loss: 0.020096 | SSIM No Spiral Loss: 0.058982 | Total Loss: 0.804661
# Recon Loss: 0.019056 | SSIM Loss: 0.062371 | Phaseless Recon Loss: 0.020013 | SSIM No Spiral Loss: 0.058817 | Total Loss: 0.801281
# Recon Loss: 0.018935 | SSIM Loss: 0.062025 | Phaseless Recon Loss: 0.019946 | SSIM No Spiral Loss: 0.058710 | Total Loss: 0.798082
# Recon Loss: 0.018801 | SSIM Loss: 0.061625 | Phaseless Recon Loss: 0.019913 | SSIM No Spiral Loss: 0.058692 | Total Loss: 0.795153
# Recon Loss: 0.018671 | SSIM Loss: 0.061190 | Phaseless Recon Loss: 0.019902 | SSIM No Spiral Loss: 0.058705 | Total Loss: 0.792345
# Recon Loss: 0.018575 | SSIM Loss: 0.060834 | Phaseless Recon Loss: 0.019872 | SSIM No Spiral Loss: 0.058667 | Total Loss: 0.789741
# Recon Loss: 0.018507 | SSIM Loss: 0.060585 | Phaseless Recon Loss: 0.019819 | SSIM No Spiral Loss: 0.058562 | Total Loss: 0.787368
# Recon Loss: 0.018468 | SSIM Loss: 0.060443 | Phaseless Recon Loss: 0.019754 | SSIM No Spiral Loss: 0.058420 | Total Loss: 0.785424
# Recon Loss: 0.018442 | SSIM Loss: 0.060371 | Phaseless Recon Loss: 0.019684 | SSIM No Spiral Loss: 0.058280 | Total Loss: 0.783887
# Recon Loss: 0.018424 | SSIM Loss: 0.060326 | Phaseless Recon Loss: 0.019609 | SSIM No Spiral Loss: 0.058126 | Total Loss: 0.782427
# Recon Loss: 0.018407 | SSIM Loss: 0.060278 | Phaseless Recon Loss: 0.019536 | SSIM No Spiral Loss: 0.057960 | Total Loss: 0.780898
# Recon Loss: 0.018382 | SSIM Loss: 0.060199 | Phaseless Recon Loss: 0.019477 | SSIM No Spiral Loss: 0.057796 | Total Loss: 0.779268
# Recon Loss: 0.018361 | SSIM Loss: 0.060129 | Phaseless Recon Loss: 0.019426 | SSIM No Spiral Loss: 0.057625 | Total Loss: 0.777706
# Recon Loss: 0.018346 | SSIM Loss: 0.060068 | Phaseless Recon Loss: 0.019381 | SSIM No Spiral Loss: 0.057479 | Total Loss: 0.776371
# Recon Loss: 0.018327 | SSIM Loss: 0.060001 | Phaseless Recon Loss: 0.019347 | SSIM No Spiral Loss: 0.057390 | Total Loss: 0.775325
# Recon Loss: 0.018315 | SSIM Loss: 0.059958 | Phaseless Recon Loss: 0.019314 | SSIM No Spiral Loss: 0.057312 | Total Loss: 0.774497
# Recon Loss: 0.018310 | SSIM Loss: 0.059936 | Phaseless Recon Loss: 0.019282 | SSIM No Spiral Loss: 0.057242 | Total Loss: 0.773847
# Recon Loss: 0.018299 | SSIM Loss: 0.059910 | Phaseless Recon Loss: 0.019255 | SSIM No Spiral Loss: 0.057185 | Total Loss: 0.773241
# Recon Loss: 0.018285 | SSIM Loss: 0.059853 | Phaseless Recon Loss: 0.019229 | SSIM No Spiral Loss: 0.057132 | Total Loss: 0.772493
# Recon Loss: 0.018269 | SSIM Loss: 0.059788 | Phaseless Recon Loss: 0.019210 | SSIM No Spiral Loss: 0.057075 | Total Loss: 0.771711
# Recon Loss: 0.018263 | SSIM Loss: 0.059773 | Phaseless Recon Loss: 0.019189 | SSIM No Spiral Loss: 0.057004 | Total Loss: 0.771143
# Recon Loss: 0.018259 | SSIM Loss: 0.059767 | Phaseless Recon Loss: 0.019170 | SSIM No Spiral Loss: 0.056946 | Total Loss: 0.770713
# Recon Loss: 0.018254 | SSIM Loss: 0.059749 | Phaseless Recon Loss: 0.019155 | SSIM No Spiral Loss: 0.056905 | Total Loss: 0.770317
# Recon Loss: 0.018247 | SSIM Loss: 0.059716 | Phaseless Recon Loss: 0.019142 | SSIM No Spiral Loss: 0.056869 | Total Loss: 0.769874
# Recon Loss: 0.018243 | SSIM Loss: 0.059702 | Phaseless Recon Loss: 0.019129 | SSIM No Spiral Loss: 0.056841 | Total Loss: 0.769571
# Recon Loss: 0.018237 | SSIM Loss: 0.059682 | Phaseless Recon Loss: 0.019122 | SSIM No Spiral Loss: 0.056834 | Total Loss: 0.769373
# Recon Loss: 0.018231 | SSIM Loss: 0.059661 | Phaseless Recon Loss: 0.019117 | SSIM No Spiral Loss: 0.056828 | Total Loss: 0.769190
# Recon Loss: 0.018227 | SSIM Loss: 0.059646 | Phaseless Recon Loss: 0.019111 | SSIM No Spiral Loss: 0.056810 | Total Loss: 0.768969
# Recon Loss: 0.018227 | SSIM Loss: 0.059648 | Phaseless Recon Loss: 0.019101 | SSIM No Spiral Loss: 0.056779 | Total Loss: 0.768775
# Recon Loss: 0.018228 | SSIM Loss: 0.059652 | Phaseless Recon Loss: 0.019093 | SSIM No Spiral Loss: 0.056758 | Total Loss: 0.768653
# Recon Loss: 0.018226 | SSIM Loss: 0.059646 | Phaseless Recon Loss: 0.019087 | SSIM No Spiral Loss: 0.056756 | Total Loss: 0.768572
# Recon Loss: 0.018220 | SSIM Loss: 0.059618 | Phaseless Recon Loss: 0.019084 | SSIM No Spiral Loss: 0.056770 | Total Loss: 0.768457
# Recon Loss: 0.018213 | SSIM Loss: 0.059588 | Phaseless Recon Loss: 0.019081 | SSIM No Spiral Loss: 0.056782 | Total Loss: 0.768320
# Recon Loss: 0.018208 | SSIM Loss: 0.059565 | Phaseless Recon Loss: 0.019076 | SSIM No Spiral Loss: 0.056786 | Total Loss: 0.768170
# Recon Loss: 0.018203 | SSIM Loss: 0.059544 | Phaseless Recon Loss: 0.019070 | SSIM No Spiral Loss: 0.056783 | Total Loss: 0.768007
# Recon Loss: 0.018198 | SSIM Loss: 0.059521 | Phaseless Recon Loss: 0.019067 | SSIM No Spiral Loss: 0.056785 | Total Loss: 0.767857
# Recon Loss: 0.018193 | SSIM Loss: 0.059496 | Phaseless Recon Loss: 0.019065 | SSIM No Spiral Loss: 0.056791 | Total Loss: 0.767722
# Recon Loss: 0.018191 | SSIM Loss: 0.059491 | Phaseless Recon Loss: 0.019060 | SSIM No Spiral Loss: 0.056786 | Total Loss: 0.767640
# Recon Loss: 0.018191 | SSIM Loss: 0.059500 | Phaseless Recon Loss: 0.019053 | SSIM No Spiral Loss: 0.056778 | Total Loss: 0.767612
# Recon Loss: 0.018186 | SSIM Loss: 0.059486 | Phaseless Recon Loss: 0.019051 | SSIM No Spiral Loss: 0.056784 | Total Loss: 0.767537
# Recon Loss: 0.018181 | SSIM Loss: 0.059469 | Phaseless Recon Loss: 0.019050 | SSIM No Spiral Loss: 0.056788 | Total Loss: 0.767438
# Recon Loss: 0.018176 | SSIM Loss: 0.059449 | Phaseless Recon Loss: 0.019050 | SSIM No Spiral Loss: 0.056795 | Total Loss: 0.767351
# Recon Loss: 0.018173 | SSIM Loss: 0.059436 | Phaseless Recon Loss: 0.019049 | SSIM No Spiral Loss: 0.056800 | Total Loss: 0.767285
# Recon Loss: 0.018172 | SSIM Loss: 0.059429 | Phaseless Recon Loss: 0.019045 | SSIM No Spiral Loss: 0.056803 | Total Loss: 0.767240
# Recon Loss: 0.018172 | SSIM Loss: 0.059430 | Phaseless Recon Loss: 0.019041 | SSIM No Spiral Loss: 0.056799 | Total Loss: 0.767215
# Recon Loss: 0.018172 | SSIM Loss: 0.059433 | Phaseless Recon Loss: 0.019039 | SSIM No Spiral Loss: 0.056797 | Total Loss: 0.767211

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1) 
plt.title("Target Image")
plt.imshow(target_spiral_image.detach().cpu(), cmap="gray")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.title("Generated Fingerprint")
plt.imshow(final_trained_fingerprint.detach().cpu(), cmap="gray")
plt.axis("off")
cv2.imwrite("../images/gen_fprint.png", (final_trained_fingerprint.detach().cpu().numpy() * 255).astype(np.uint8))
plt.show()

# %%
final_trained_fingerprint = 0.5 * (1.0 + torch.cos(phase_map + spiral_phase_map))

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.title("final phase")
plt.imshow((phase_map + spiral_phase_map).detach().cpu(), cmap="gray")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.title("Generated Fingerprint")
plt.imshow(final_trained_fingerprint.detach().cpu(), cmap="gray")
plt.axis("off")
plt.show()

# %%
print(phase_map)

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(phase_map.detach().cpu(), cmap="gray")
plt.colorbar()
plt.title("Trained Phase Map")
plt.axis("off")

plt.subplot(1, 2, 2)
final_fingerprint_without_spiral = 0.5 * (1.0 + torch.cos(phase_map))
plt.imshow(final_fingerprint_without_spiral.detach().cpu(), cmap="gray")
plt.title("Generated Fingerprint without Spiral Phase")
plt.axis("off")

plt.show()
plt.imshow(spiral_phase_map.detach().cpu(), cmap="gray")
plt.colorbar()
plt.title("Spiral Phase Map")
plt.axis("off")
plt.show()
# Out:
# Parameter containing:
# tensor([[1.8947, 2.1147, 2.3283,  ..., 7.4723, 7.2625, 7.0682],
#         [2.0986, 2.3360, 3.8469,  ..., 7.7434, 7.4901, 7.2647],
#         [2.3196, 2.6037, 3.6036,  ..., 8.0701, 7.7558, 7.4874],
#         ...,
#         [3.8441, 3.6029, 3.3606,  ..., 3.1471, 3.3649, 3.6065],
#         [4.0694, 3.8416, 3.6036,  ..., 3.3810, 3.6223, 3.8406],
#         [4.2737, 4.0589, 3.8319,  ..., 3.6090, 3.8295, 4.0380]],
#        requires_grad=True)

# %%
# 5. Plot
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.title("Original (May be eclipsed)")
# Convert original to numpy for plotting, handling potential infinite values roughly
original_np = phase_map.detach().cpu().squeeze().numpy()
plt.imshow(original_np, cmap='gray')
plt.colorbar()

plt.tight_layout()
plt.show()

# %%
original_fprint = cv2.imread("../images/cont_phase.jpg", cv2.IMREAD_GRAYSCALE)
gen_fprint = cv2.imread("../images/gen_fprint.png", cv2.IMREAD_GRAYSCALE)

# check if path exists
print(os.path.exists("../images/gen_fprint.png"))

# normalize both
original_fprint = original_fprint / original_fprint.max()
gen_fprint = gen_fprint / gen_fprint.max()

of = torch.from_numpy(original_fprint)
gf = torch.from_numpy(gen_fprint)

print(of.shape, gf.shape)

fft_of = torch.fft.rfft2(of, norm='ortho')
fft_gf = torch.fft.rfft2(gf, norm='ortho')

mag_fft_of = torch.log(torch.abs(fft_of) + 1e-8)
mag_fft_gf = torch.log(torch.abs(fft_gf) + 1e-8)

phase_fft_of = torch.angle(fft_of)
phase_fft_gf = torch.angle(fft_gf)


plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(mag_fft_of, cmap='inferno')
plt.colorbar()


plt.subplot(1, 2, 2)
plt.imshow(mag_fft_gf, cmap="inferno")
plt.colorbar()
plt.show()


plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(phase_fft_of, cmap="twilight")

plt.subplot(1, 2, 2)
plt.imshow(phase_fft_gf, cmap="twilight")
plt.show()
# Out:
# False
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 8
#       5 print(os.path.exists("../images/gen_fprint.png"))
#       7 # normalize both
# ----> 8 original_fprint = original_fprint / original_fprint.max()
#       9 gen_fprint = gen_fprint / gen_fprint.max()
#      11 of = torch.from_numpy(original_fprint)
#
# AttributeError: 'NoneType' object has no attribute 'max'
